# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
# %tensorflow_version 2.x

# %%
# %cd /content/drive/MyDrive
# !mkdir option
# %cd option
# !git clone https://github.com/tensorflow/models.git
# Out:
# /content/drive/MyDrive
# mkdir: cannot create directory ‘option’: File exists
# /content/drive/MyDrive/option
# fatal: destination path 'models' already exists and is not an empty directory.

# %%
# %cd /content/drive/MyDrive/option/models/research
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/drive/MyDrive/option/models/research

# %%
# !cp object_detection/packages/tf2/setup.py . 
# !python -m pip install .
# Out:
# Processing /content/drive/My Drive/option/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#      |████████████████████████████████| 9.8 MB 33.0 MB/s
# ...
#      |████████████████████████████████| 352 kB 54.2 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 40.1 MB/s
# ...
#      |████████████████████████████████| 211 kB 54.1 MB/s
# ...
#      |████████████████████████████████| 636 kB 43.5 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 16.8 MB/s
# ...
#      |████████████████████████████████| 90 kB 9.6 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 99 kB 8.9 MB/s
# ...

# %%
#TEST your installation
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# 2021-09-24 08:13:44.578883: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-09-24 08:13:44.578964: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (1da751dfee49): /proc/driver/nvidia/version does not exist
# Running tests under Python 3.7.12: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# W0924 08:13:44.917971 140435708012416 model_builder.py:1091] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.85s
# I0924 08:13:45.431615 140435708012416 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.85s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# ...

# %%
# %cd /content/drive/MyDrive/option
# !git clone https://github.com/aalpatya/detect_hands.git
# Out:
# /content/drive/MyDrive/option
# Cloning into 'detect_hands'...
# remote: Enumerating objects: 206, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 206 (delta 38), reused 56 (delta 20), pack-reused 118
# Receiving objects: 100% (206/206), 53.76 MiB | 13.76 MiB/s, done.
# Resolving deltas: 100% (81/81), done.
# Checking out files: 100% (100/100), done.

# %%
# !cp detect_hands/egohands_dataset_to_csv.py .
# !pwd

# !python egohands_dataset_to_csv.py
# Out:
# /content/drive/My Drive/option
# Egohands dataset already downloaded.
# Files already extracted.
# CSV generation for each file complete!
# Generating train/test folders
# Train/test content generation complete!
# Saved label csv for  train images/train/train_labels.csv
# Saved label csv for  test images/test/test_labels.csv

# %%
# %cd /content/drive/MyDrive/option
# !cp detect_hands/generate_tfrecord.py .
# For the train dataset
# !python generate_tfrecord.py --csv_input=images/train/train_labels.csv  --output_path=train.record
# For the test dataset
# !python generate_tfrecord.py --csv_input=images/test/test_labels.csv  --output_path=test.record
# Out:
# /content/drive/MyDrive/option
# 2021-09-24 08:30:15.652019: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-09-24 08:30:15.652096: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (1da751dfee49): /proc/driver/nvidia/version does not exist
# Successfully created the TFRecords: /content/drive/My Drive/option/train.record
# 2021-09-24 08:30:20.010233: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-09-24 08:30:20.010313: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (1da751dfee49): /proc/driver/nvidia/version does not exist
# Successfully created the TFRecords: /content/drive/My Drive/option/test.record

# %%
# %cd /content/drive/MyDrive/option
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Unzip
# !tar -xzvf ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Out:
# /content/drive/MyDrive/option
# --2021-09-24 08:30:39--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 172.217.164.144, 2607:f8b0:4004:82f::2010
# Connecting to download.tensorflow.org (download.tensorflow.org)|172.217.164.144|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  61.1MB/s    in 0.3s
#
# 2021-09-24 08:30:39 (61.1 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir=/content/drive/MyDrive/output_training/train

# %%
# %cd /content/drive/MyDrive/option/models/research/object_detection/
#train 
# !python model_main_tf2.py \
--pipeline_config_path=/content/drive/MyDrive/option/detect_hands/model_data/ssd_mobilenet_v2_fpn_320/pipeline.config \
--model_dir=/content/drive/MyDrive/option/output_training --alsologtostderr
# Out:
# /content/drive/MyDrive/option/models/research/object_detection
# 2021-09-24 08:58:54.247993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-24 08:58:54.258573: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-24 08:58:54.259435: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-24 08:58:54.261478: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# fix tfod installation (protobuf issue)
# %%bash
cd /content/drive/MyDrive/option/models/research/
protoc object_detection/protos/*.proto --python_out=.
cp object_detection/packages/tf2/setup.py .
python -m pip install .
# Out:
# Processing /content/drive/MyDrive/option/models/research
# ...
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1665627 sha256=7d3d5b8ca8581b1670408f912f41d46d1263f561c7204cfe4b3fc173add94b74
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e7j6kod8/wheels/bf/0e/29/88bbfc7949eed213e5e42aeecc3577f9fd6992d97c4a4da602
# ...
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22258 sha256=d28853298618e643ba05355ef14d48a77680166f19c9f08e64e0115fff3726d7
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
# ...
#   Created wheel for avro-python3: filename=avro_python3-1.9.2.1-py3-none-any.whl size=43512 sha256=8e806d766970c3987cfcc43e16c78fed15192968df2a25c2e114541d5318a598
#   Stored in directory: /root/.cache/pip/wheels/bc/49/5f/fdb5b9d85055c478213e0158ac122b596816149a02d82e0ab1
# ...
