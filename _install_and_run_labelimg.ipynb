# %%
# !pwd
# !ls
# Out:
# /Users/oak/Documents/GitHub/option
# 0_Slides.ipynb                        Tensorflow
# 1. Image Collection.ipynb             Untitled.ipynb
# 2. Training and Detection-Copy1.ipynb _create_venv_and_add_to_jupyter.ipynb
# 2. Training and Detection.ipynb       simple_images

# %%
import os

# %%
# !pip install pyqt5 lxml
# !brew install qt qt5
# !brew install libxml2
# !brew install pyqt5
# Out:
# Requirement already satisfied: pyqt5 in /Users/oak/tfod/lib/python3.8/site-packages (5.15.4)
# Requirement already satisfied: lxml in /Users/oak/tfod/lib/python3.8/site-packages (4.6.3)
# Requirement already satisfied: PyQt5-Qt5>=5.15 in /Users/oak/tfod/lib/python3.8/site-packages (from pyqt5) (5.15.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in /Users/oak/tfod/lib/python3.8/site-packages (from pyqt5) (12.9.0)
# Updating Homebrew...
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# abricate                   fuse-overlayfs             pillow
# actionlint                 ghostunnel                 pkg-config-wrapper
# age                        git-xargs                  pkgconf
# airspyhf                   go@1.16                    plow
# alda                       graphqurl                  poppler-qt5
# alembic                    gtop                       procps
# alerter                    h2c                        psalm
# amfora                     hcl2json                   px
# ansilove                   htmlq                      py-spy
# apache-pulsar              hubble                     pydocstyle
# apt                        i2c-tools                  pyflow
# argocd-vault-plugin        influxdb-cli               pyoxidizer
# artillery                  iredis                     pyright
# atop                       jello                      python-launcher
# aws-vault                  joplin-cli                 pythran
# baidupcs-go                jpdfbookmarks              red-tldr
# bash_unit                  jrsonnet                   reproc
# basis_universal            kalker                     rhit
# bat-extras                 kn                         rollup
# bbtools                    kubeconform                ronn
# bgpq4                      lexbor                     rover
# bioperl                    libaec                     rpg-cli
# bosh-cli                   libfuse@2                  rsc_2fa
# bottom                     libmng                     s4cmd
# bubblewrap                 librespot                  sail
# buildpulse-test-reporter   librist                    samba
# bupstash                   licensefinder              scorecard
# cargo-bloat                lima                       scry
# cargo-llvm-lines           linux-headers@4.15         selene
# cargo-outdated             lit                        singularity
# chrpath                    locust                     slides
# cilium-cli                 macos-term-size            slirp4netns
# ciphey                     mailcatcher                soapyrtlsdr
# clarinet                   mariadb@10.5               soapysdr
# conmon                     maturin                    solana
# cosign                     mbedtls@2                  spectra
# cppzmq                     microsocks                 spirv-llvm-translator
# cruft                      mimalloc                   spot
# crun                       moar                       sql-lint
# cue                        mrbayes                    sqlbench
# darglint                   msgpack-cxx                sqsmover
# datree                     multi-git-status           stylua
# demumble                   murex                      svgbob
# detect-secrets             nanoflann                  terminator
# doc8                       nbsdgames                  tmuxp
# docuum                     ncc                        tracker
# dotbot                     newrelic-infra-agent       uftrace
# drill                      notcurses                  umple
# eigenpy                    ns-3                       vala-language-server
# elfutils                   onedrive                   vespa-cli
# esbuild                    openfpgaloader             vite
# f2                         openliberty-jakartaee8     viu
# fann                       openliberty-microprofile4  vue-cli
# fanyi                      openliberty-webprofile8    wasmtime
# fastq-tools                opensearch-dashboards      waypoint
# fcp                        osc-cli                    wildmidi
# firefoxpwa                 ots                        xauth
# flamebearer                pari-elldata               xsel
# fluid-synth@2.1            pari-galdata               yt-dlp
# frum                       pari-galpol                zet
# fst                        pari-seadata
# func-e                     pari-seadata-big
# ==> Updated Formulae
# Updated 4905 formulae.
# ==> Renamed Formulae
# envoy@1.17 -> envoy@1.18                 prestosql -> trino
# kafkacat -> kcat                         weboob -> woob
# linux-headers -> linux-headers@4.4       wxmac -> wxwidgets
# parallelstl -> onedpl                    wxmac@3.0 -> wxwidgets@3.0
# ==> Deleted Formulae
# boost@1.57                               procyon-decompiler
# boost@1.60                               terraform-provisioner-ansible
# giter8                                   tj
# libinfinity                              vavrdiasm
# ==> New Casks
# 8x8-work                                 millie
# adguard-vpn                              mimestream
# adrive                                   moebius
# affinity-designer                        mweb-pro
# affinity-photo                           nimblenote
# affinity-publisher                       notunes
# archi                                    nudge
# asana                                    odbc-manager
# betterdiscord-installer                  open-video-downloader
# bit-fiddle                               openloco
# blackhole-64ch                           p4
# blockbench                               physics-101
# burp-suite-professional                  pktriot
# castr                                    polkadot-js
# cinc-workstation                         portx
# classroom-mode-for-minecraft             pulse
# clay                                     radar
# clock-signal                             redis-pro
# deepnest                                 remix-ide
# devkinsta                                remotion
# diagnostics                              safe-exam-browser
# disk-expert                              samsung-dex
# dropzone                                 shimonote
# duplicate-file-finder                    shottr
# ears                                     sigmaos
# enigma                                   sleek
# epilogue-operator                        smplayer
# far2l                                    sonic-robo-blast-2
# final-fantasy-xiv-online                 sonic-robo-blast-2-kart
# flacon                                   sparrow
# fluent-reader                            sqlight
# foxglove-studio                          stork
# gcs                                      tabby
# goneovim                                 temurin
# gosign                                   tic80
# guilded                                  touch-portal
# hush                                     touchosc
# hyperkey                                 transfer
# infra                                    trezor-suite
# itraffic                                 ubports-installer
# jiohome                                  unexpectedly
# kdocs                                    universal-battle
# keyboardholder                           universal-gcode-platform
# keyman                                   vial
# lagrange                                 vsd-viewer
# leapp                                    vsdx-annotator
# librewolf                                vym
# maccleaner-pro                           wezterm
# maestral                                 wifi-explorer-pro
# mathcha-notebook                         wing-personal
# maxon                                    wondershare-edrawmax
# memory-cleaner                           yippy
# midi-router-client                       zebra2
# midiview
# ==> Updated Casks
# Updated 1542 casks.
# ==> Deleted Casks
# 3cxphone                                 nure
# adafruit-arduino                         obyte
# adobe-lens-profile-creator               open-ecard
# adware-removal-tool                      otter-browser
# agfeo-dashboard                          pastor
# anytrans                                 pdftotext
# anytrans-for-android                     phonebrowse
# axe-electrum                             phoneclean
# baiducloud                               phonerescue
# beautune                                 phonetrans
# beoplay-software-update                  playnow
# blue-jeans-browser-plugin                plecs-standalone
# boonzi                                   pomolectron
# brooklite                                privatus
# caramba-switcher                         pro-fit
# colormunki-photo                         qtum
# deadbeef                                 qyooo
# dnagedcom                                rcloneosx
# dragthing                                rubitrack-pro
# dukto                                    s3stat-setup
# eaccess                                  scrooo
# edrawmax                                 shoes
# elpki                                    simplelink-msp432e4-sdk
# finisher-fluxx                           spectrum
# finisher-micro                           stageplotpro
# finisher-neo                             superbeam
# flow-e                                   tbs-studio
# fluxcenter                               tcl
# fm3-edit                                 terminus
# foreman                                  thetube
# imarisviewer                             todos
# imobie-m1-app-checker                    trufont
# instant-articles-builder                 uberconference
# instasizer                               unity-appletv-support-for-editor
# jabt-flow                                unity-download-assistant
# jidusm                                   unity-linux-il2cpp-support-for-editor
# lektor                                   unity-macos-il2cpp-support-for-editor
# lightwright                              unity-standard-assets
# locklizard-safeguard-viewer              unity-web-player
# macclean                                 utox
# macintosh-explorer                       wanna
# mapillary-uploader                       wingpersonal
# modulair                                 wolfram-player
# monitorearth                             xamarin
# mweb                                     zbuc-imgur
# noraswitch
# ==> Downloading https://ghcr.io/v2/homebrew/core/assimp/manifests/5.0.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/assimp/blobs/sha256:b2450bc0cc2
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/manifests/1.0.9
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/blobs/sha256:a382d95787c
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/dbus/manifests/1.12.20
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/dbus/blobs/sha256:23513ea5d7520
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/double-conversion/manifests/3.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/double-conversion/blobs/sha256:
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.11.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/blobs/sha256:619ef51d1
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pcre/manifests/8.45
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pcre/blobs/sha256:180d88dc2230e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdbm/manifests/1.20
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdbm/blobs/sha256:2c62d9ef89fc3
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/1.1/manifests/1.1.1l
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/1.1/blobs/sha256:9c8490
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/manifests/3.36.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/blobs/sha256:3665b753562
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.9/manifests/3.9.7
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.9/blobs/sha256:3041269
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.70.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:9050f98ed8bda
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/hunspell/manifests/1.7.0_2-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/hunspell/blobs/sha256:d5144178e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/manifests/2.0.33
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/blobs/sha256:7c7ae386ed0
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libb2/manifests/0.98.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libb2/blobs/sha256:fb9f331b6c55
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pcre2/manifests/10.37_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pcre2/blobs/sha256:0e40c8534a5f
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.2.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/blobs/sha256:43953ec86a790
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/manifests/1.5.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/blobs/sha256:571d031a8fe1b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/qt/manifests/6.1.3-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/qt/blobs/sha256:c24b067cb5fa13d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/qt/5/manifests/5.15.2-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/qt/5/blobs/sha256:02280e07b5fe3
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Installing dependencies for qt: assimp, brotli, dbus, double-conversion, freetype, pcre, gdbm, openssl@1.1, sqlite, python@3.9, glib, hunspell, jasper, libb2, pcre2, webp and zstd
# ==> Installing qt dependency: assimp
# ==> Pouring assimp--5.0.1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/assimp/5.0.1: 100 files, 12.5MB
# ==> Installing qt dependency: brotli
# ==> Pouring brotli--1.0.9.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/brotli/1.0.9: 25 files, 2.3MB
# ==> Installing qt dependency: dbus
# ==> Pouring dbus--1.12.20.catalina.bottle.tar.gz
# ==> /usr/local/Cellar/dbus/1.12.20/bin/dbus-uuidgen --ensure=/usr/local/var/lib/
# 🍺  /usr/local/Cellar/dbus/1.12.20: 76 files, 2.1MB
# ==> Installing qt dependency: double-conversion
# ==> Pouring double-conversion--3.1.5_1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/double-conversion/3.1.5_1: 24 files, 242.3KB
# ==> Installing qt dependency: freetype
# ==> Pouring freetype--2.11.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/freetype/2.11.0: 66 files, 2.5MB
# ==> Installing qt dependency: pcre
# ==> Pouring pcre--8.45.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/pcre/8.45: 204 files, 5.8MB
# ==> Installing qt dependency: gdbm
# ==> Pouring gdbm--1.20.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/gdbm/1.20: 24 files, 822.1KB
# ==> Installing qt dependency: openssl@1.1
# ==> Pouring openssl@1.1--1.1.1l.catalina.bottle.tar.gz
# ==> Regenerating CA certificate bundle from keychain, this may take a while...
# 🍺  /usr/local/Cellar/openssl@1.1/1.1.1l: 8,073 files, 18.5MB
# ==> Installing qt dependency: sqlite
# ==> Pouring sqlite--3.36.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/sqlite/3.36.0: 11 files, 4.2MB
# ==> Installing qt dependency: python@3.9
# ==> Pouring python@3.9--3.9.7.catalina.bottle.tar.gz
# ==> /usr/local/Cellar/python@3.9/3.9.7/bin/python3 -m ensurepip
# ==> /usr/local/Cellar/python@3.9/3.9.7/bin/python3 -m pip install -v --no-deps -
# 🍺  /usr/local/Cellar/python@3.9/3.9.7: 3,080 files, 54.7MB
# ==> Installing qt dependency: glib
# ==> Pouring glib--2.70.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/glib/2.70.0: 444 files, 21MB
# ==> Installing qt dependency: hunspell
# ==> Pouring hunspell--1.7.0_2.catalina.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/hunspell/1.7.0_2: 38 files, 1.8MB
# ==> Installing qt dependency: jasper
# ==> Pouring jasper--2.0.33.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/jasper/2.0.33: 41 files, 1.3MB
# ==> Installing qt dependency: libb2
# ==> Pouring libb2--0.98.1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libb2/0.98.1: 8 files, 242.3KB
# ==> Installing qt dependency: pcre2
# ==> Pouring pcre2--10.37_1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/pcre2/10.37_1: 230 files, 6.2MB
# ==> Installing qt dependency: webp
# ==> Pouring webp--1.2.1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/webp/1.2.1: 39 files, 2.4MB
# ==> Installing qt dependency: zstd
# ==> Pouring zstd--1.5.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/zstd/1.5.0: 31 files, 3.5MB
# ==> Installing qt
# ==> Pouring qt--6.1.3.catalina.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/qt/6.1.3: 9,837 files, 190.3MB
# ==> `brew cleanup` has not been run in the last 30 days, running now...
# Removing: /Users/oak/Library/Caches/Homebrew/aom--3.1.0... (4MB)
# Removing: /Users/oak/Library/Caches/Homebrew/atk--2.36.0... (476.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/bdw-gc--8.0.4_2... (513.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/c-ares--1.17.1... (162.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/cairo--1.16.0_5... (1.8MB)
# Removing: /Users/oak/Library/Caches/Homebrew/cmake--3.20.3... (18.4MB)
# Removing: /Users/oak/Library/Caches/Homebrew/faac--1.29.9.2... (85.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/faad2--2.8.8... (640.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/ffmpeg--4.4_1... (19.7MB)
# Removing: /Users/oak/Library/Caches/Homebrew/flac--1.3.3... (615.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/fontconfig--2.13.1... (1.2MB)
# Removing: /usr/local/Cellar/freetype/2.10.4... (64 files, 2.3MB)
# Removing: /Users/oak/Library/Caches/Homebrew/freetype--2.10.4... (901.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/frei0r--1.7.0... (418.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/fribidi--1.0.10... (129.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gd--2.3.2... (303.9KB)
# Removing: /usr/local/Cellar/gdbm/1.19... (24 files, 789KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gdbm--1.19... (207.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gdk-pixbuf--2.42.6... (790.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gettext--0.21... (8.5MB)
# Removing: /Users/oak/Library/Caches/Homebrew/giflib--5.2.1... (145KB)
# Removing: /usr/local/Cellar/glib/2.68.2... (442 files, 21MB)
# Removing: /Users/oak/Library/Caches/Homebrew/glib--2.68.2... (6.3MB)
# Removing: /Users/oak/Library/Caches/Homebrew/glib-networking--2.68.1... (158.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gmp--6.2.1... (1MB)
# Removing: /Users/oak/Library/Caches/Homebrew/gobject-introspection--1.68.0... (1.8MB)
# Removing: /Users/oak/Library/Caches/Homebrew/graphene--1.10.6... (129.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/graphite2--1.3.14... (93.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gsettings-desktop-schemas--40.0... (1.4MB)
# Removing: /Users/oak/Library/Caches/Homebrew/gst-libav--1.18.4... (259.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gst-plugins-bad--1.18.4... (4.8MB)
# Removing: /Users/oak/Library/Caches/Homebrew/gst-plugins-base--1.18.4... (4.1MB)
# Removing: /Users/oak/Library/Caches/Homebrew/gst-plugins-good--1.18.4... (4.2MB)
# Removing: /Users/oak/Library/Caches/Homebrew/gst-python--1.18.4... (128.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gst-rtsp-server--1.18.4... (469.1KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gstreamer--1.18.4... (3.4MB)
# Removing: /Users/oak/Library/Caches/Homebrew/gtk+3--3.24.29... (14.6MB)
# Removing: /Users/oak/Library/Caches/Homebrew/gts--0.7.6_2... (395.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/guile--3.0.7... (11.6MB)
# Removing: /Users/oak/Library/Caches/Homebrew/harfbuzz--2.8.1... (2MB)
# Removing: /Users/oak/Library/Caches/Homebrew/hicolor-icon-theme--0.17... (15.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/icu4c--69.1... (27.2MB)
# Removing: /usr/local/Cellar/jasper/2.0.32... (40 files, 1018.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/jasper--2.0.32... (311.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/jemalloc--5.2.1_1... (641.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/jpeg--9d... (309.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/lame--3.100... (774KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libass--0.15.1... (216.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libbluray--1.3.0... (318.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libcuefile--r475... (67.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libev--4.33... (146.0KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libevent--2.1.12... (681.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libffi--3.3_3... (167.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libidn2--2.3.1... (246.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libmms--0.6.4... (57.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libnice--0.1.18... (253.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libpng--1.6.37... (441.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libpsl--0.21.1_3... (56.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libpthread-stubs--0.4... (3.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libreplaygain--r475... (9.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libsamplerate--0.1.9_1... (2.6MB)
# Removing: /Users/oak/Library/Caches/Homebrew/libshout--2.4.5... (115.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libsndfile--1.0.31... (586.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libsodium--1.0.18_1... (359KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libsoup--2.72.0... (601.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libsoxr--0.1.3... (101.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libtasn1--4.17.0... (148.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libtiff--4.3.0... (1.2MB)
# Removing: /Users/oak/Library/Caches/Homebrew/libtool--2.4.6_3... (1007.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libunistring--0.9.10... (1.4MB)
# Removing: /Users/oak/Library/Caches/Homebrew/libusrsctp--0.9.5.0... (277.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libvidstab--1.1.0... (46.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libvorbis--1.3.7... (576.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libvpx--1.10.0... (1MB)
# Removing: /Users/oak/Library/Caches/Homebrew/libxau--1.0.9... (28.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libxcb--1.14_1... (989.0KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libxdmcp--1.1.3... (30.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libxext--1.3.4... (104.1KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libxrender--0.9.10... (47.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/little-cms2--2.12... (397.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/lsusb--1.0... (4.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/lzo--2.10... (144KB)
# Removing: /Users/oak/Library/Caches/Homebrew/m4--1.4.18... (232.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/mpdecimal--2.5.1... (548.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/musepack--r475... (168.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/nghttp2--1.43.0... (970.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/opencore-amr--0.1.5... (307.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/openjpeg--2.4.0... (2MB)
# Removing: /usr/local/Cellar/openssl@1.1/1.1.1k... (8,071 files, 18.5MB)
# Removing: /Users/oak/Library/Caches/Homebrew/openssl@1.1--1.1.1k... (5.4MB)
# Removing: /Users/oak/Library/Caches/Homebrew/opus--1.3.1... (444KB)
# Removing: /Users/oak/Library/Caches/Homebrew/orc--0.4.32... (271.6KB)
# Removing: /usr/local/Cellar/pcre/8.44... (204 files, 5.5MB)
# Removing: /Users/oak/Library/Caches/Homebrew/pcre--8.44... (1.8MB)
# Removing: /Users/oak/Library/Caches/Homebrew/pixman--0.40.0... (498.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/pkg-config--0.29.2_3... (234.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/protobuf--3.17.2... (4.6MB)
# Removing: /Users/oak/Library/Caches/Homebrew/pygobject3--3.40.1... (257.6KB)
# Removing: /usr/local/Cellar/python@3.9/3.9.5... (3,129 files, 55MB)
# Removing: /Users/oak/Library/Caches/Homebrew/python@3.9--3.9.5... (13.5MB)
# Removing: /Users/oak/Library/Caches/Homebrew/rav1e--0.4.1_1... (34.9MB)
# Removing: /Users/oak/Library/Caches/Homebrew/readline--8.1... (536.1KB)
# Removing: /Users/oak/Library/Caches/Homebrew/rtmpdump--2.4+20151223_1... (168.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/sdl2--2.0.14_1... (1.4MB)
# Removing: /Users/oak/Library/Caches/Homebrew/speex--1.2.0... (519.6KB)
# Removing: /usr/local/Cellar/sqlite/3.35.5... (11 files, 4.2MB)
# Removing: /Users/oak/Library/Caches/Homebrew/sqlite--3.35.5... (2.0MB)
# Removing: /Users/oak/Library/Caches/Homebrew/srt--1.4.3... (1.7MB)
# Removing: /Users/oak/Library/Caches/Homebrew/srtp--2.3.0... (165KB)
# Removing: /Users/oak/Library/Caches/Homebrew/taglib--1.12... (423.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/tesseract--4.1.1... (11.9MB)
# Removing: /Users/oak/Library/Caches/Homebrew/theora--1.1.1... (718.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/unbound--1.13.1... (2.6MB)
# Removing: /usr/local/Cellar/webp/1.2.0... (39 files, 2.4MB)
# Removing: /Users/oak/Library/Caches/Homebrew/webp--1.2.0... (874.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/wget--1.21.1... (1.4MB)
# Removing: /Users/oak/Library/Caches/Homebrew/x264--r3049... (2.3MB)
# Removing: /Users/oak/Library/Caches/Homebrew/x265--3.5... (5MB)
# Removing: /Users/oak/Library/Caches/Homebrew/xorgproto--2021.4... (695.1KB)
# Removing: /Users/oak/Library/Caches/Homebrew/xvid--1.3.7... (452.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/xz--5.2.5... (387.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/zeromq--4.3.4... (1.6MB)
# Removing: /Users/oak/Library/Caches/Homebrew/zimg--3.0.1... (686.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gobject-introspection_bottle_manifest--1.68.0... (11.1KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libidn2_bottle_manifest--2.3.1... (5.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/guile_bottle_manifest--3.0.7... (6.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/cairo_bottle_manifest--1.16.0_5... (11.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/xorgproto_bottle_manifest--2021.4... (2.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libsndfile_bottle_manifest--1.0.31... (5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gst-plugins-base_bottle_manifest--1.18.4... (14.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/jasper_bottle_manifest--2.0.32... (4.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gts_bottle_manifest--0.7.6_2... (8.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/lsusb_bottle_manifest--1.0... (6.0KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gnutls_bottle_manifest--3.6.15-1... (8.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/rav1e_bottle_manifest--0.4.1_1... (4.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libogg_bottle_manifest--1.3.4-1... (4.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libass_bottle_manifest--0.15.1... (10.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/graphite2_bottle_manifest--1.3.14... (4.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/zimg_bottle_manifest--3.0.1... (5.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libvidstab_bottle_manifest--1.1.0-1... (5.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/sdl2_bottle_manifest--2.0.14_1... (4.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/speex_bottle_manifest--1.2.0... (7.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/xz_bottle_manifest--5.2.5... (4.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gst-libav_bottle_manifest--1.18.4... (22.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/p11-kit_bottle_manifest--0.23.22... (4.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/tesseract_bottle_manifest--4.1.1... (6.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/rtmpdump_bottle_manifest--2.4+20151223_1... (5.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/aom_bottle_manifest--3.1.0... (4.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/librsvg_bottle_manifest--2.50.5... (11.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/orc_bottle_manifest--0.4.32... (5.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libtool_bottle_manifest--2.4.6_3... (4.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libepoxy_bottle_manifest--1.5.7... (4.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/jemalloc_bottle_manifest--5.2.1_1... (5.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/harfbuzz_bottle_manifest--2.8.1... (10.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libxau_bottle_manifest--1.0.9... (5.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/hicolor-icon-theme_bottle_manifest--0.17... (6.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/x264_bottle_manifest--r3049... (4.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/srt_bottle_manifest--1.4.3... (4.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libxext_bottle_manifest--1.3.4... (6.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libreplaygain_bottle_manifest--r475-1... (6.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/c-ares_bottle_manifest--1.17.1... (4.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/atk_bottle_manifest--2.36.0... (7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/opencore-amr_bottle_manifest--0.1.5... (7.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/graphene_bottle_manifest--1.10.6... (6.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/lame_bottle_manifest--3.100... (6.1KB)
# Removing: /Users/oak/Library/Caches/Homebrew/pcre_bottle_manifest--8.44... (6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libusrsctp_bottle_manifest--0.9.5.0... (4.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/openssl@1.1_bottle_manifest--1.1.1k... (4.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libmms_bottle_manifest--0.6.4-2... (8.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libtasn1_bottle_manifest--4.17.0... (4.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gst-rtsp-server_bottle_manifest--1.18.4... (12.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libsamplerate_bottle_manifest--0.1.9_1-1... (6.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/fribidi_bottle_manifest--1.0.10... (4.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/openjpeg_bottle_manifest--2.4.0... (5.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/x265_bottle_manifest--3.5-1... (4.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/nettle_bottle_manifest--3.7.2... (4.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/fontconfig_bottle_manifest--2.13.1... (7.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/readline_bottle_manifest--8.1... (4.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libnice_bottle_manifest--0.1.18-1... (9.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/ffmpeg_bottle_manifest--4.4_1... (22.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/webp_bottle_manifest--1.2.0... (5.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gsettings-desktop-schemas_bottle_manifest--40.0... (7.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libshout_bottle_manifest--2.4.5... (5.1KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libxrender_bottle_manifest--0.9.10... (6.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libffi_bottle_manifest--3.3_3... (4.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/flac_bottle_manifest--1.3.3-1... (5.1KB)
# Removing: /Users/oak/Library/Caches/Homebrew/xvid_bottle_manifest--1.3.7... (4.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/taglib_bottle_manifest--1.12... (4.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/pixman_bottle_manifest--0.40.0... (4.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/icu4c_bottle_manifest--69.1... (4.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/giflib_bottle_manifest--5.2.1... (4.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/snappy_bottle_manifest--1.1.8... (4.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gdk-pixbuf_bottle_manifest--2.42.6... (7.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/sqlite_bottle_manifest--3.35.5... (4.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/freetype_bottle_manifest--2.10.4... (5.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/rubberband_bottle_manifest--1.9.1... (5.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/py3cairo_bottle_manifest--1.20.0_1... (9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libpng_bottle_manifest--1.6.37... (5.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/portable-ruby-2.6.3_2.yosemite.bottle.tar.gz... (9.1MB)
# Removing: /Users/oak/Library/Caches/Homebrew/libtiff_bottle_manifest--4.3.0... (4.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libxdmcp_bottle_manifest--1.1.3... (5.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/netpbm_bottle_manifest--10.86.21... (5.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libxcb_bottle_manifest--1.14_1-1... (8.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libsoxr_bottle_manifest--0.1.3-1... (5.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/little-cms2_bottle_manifest--2.12... (4.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/leptonica_bottle_manifest--1.80.0... (6.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gdbm_bottle_manifest--1.19... (4.1KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libvorbis_bottle_manifest--1.3.7... (5.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libbluray_bottle_manifest--1.3.0... (5.1KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gst-python_bottle_manifest--1.18.4... (9.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/lzo_bottle_manifest--2.10... (6.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gst-plugins-good_bottle_manifest--1.18.4... (20.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libev_bottle_manifest--4.33... (4.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gst-plugins-bad_bottle_manifest--1.18.4... (19.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libpsl_bottle_manifest--0.21.1_3... (4.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/faad2_bottle_manifest--2.8.8... (6.0KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gmp_bottle_manifest--6.2.1... (5.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/faac_bottle_manifest--1.29.9.2... (6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/mpdecimal_bottle_manifest--2.5.1... (4.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/dav1d_bottle_manifest--0.8.2... (4.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/pygobject3_bottle_manifest--3.40.1... (9.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libsodium_bottle_manifest--1.0.18_1... (4.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/pango_bottle_manifest--1.48.4... (10.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/m4_bottle_manifest--1.4.18-1... (4.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/graphviz_bottle_manifest--2.47.1... (13.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/jpeg_bottle_manifest--9d... (4.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/glib-networking_bottle_manifest--2.68.1... (10.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gd_bottle_manifest--2.3.2... (5.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gettext_bottle_manifest--0.21... (6.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libunistring_bottle_manifest--0.9.10... (6.1KB)
# Removing: /Users/oak/Library/Caches/Homebrew/bdw-gc_bottle_manifest--8.0.4_2... (4.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/glib_bottle_manifest--2.68.2... (9.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/python@3.9_bottle_manifest--3.9.5... (12.5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/nghttp2_bottle_manifest--1.43.0... (5.1KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libevent_bottle_manifest--2.1.12... (5.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libpthread-stubs_bottle_manifest--0.4... (5.4KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libx11_bottle_manifest--1.7.0... (7.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/zeromq_bottle_manifest--4.3.4... (4.6KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libvpx_bottle_manifest--1.10.0... (4.2KB)
# Removing: /Users/oak/Library/Caches/Homebrew/unbound_bottle_manifest--1.13.1... (6.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gtk+3_bottle_manifest--3.24.29... (12.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/pkg-config_bottle_manifest--0.29.2_3... (4.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libcuefile_bottle_manifest--r475-1... (6.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/musepack_bottle_manifest--r475-1... (5KB)
# Removing: /Users/oak/Library/Caches/Homebrew/gstreamer_bottle_manifest--1.18.4... (7.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/srtp_bottle_manifest--2.3.0... (4.8KB)
# Removing: /Users/oak/Library/Caches/Homebrew/theora_bottle_manifest--1.1.1-4... (4.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/frei0r_bottle_manifest--1.7.0... (4.9KB)
# Removing: /Users/oak/Library/Caches/Homebrew/opus_bottle_manifest--1.3.1-1... (4.7KB)
# Removing: /Users/oak/Library/Caches/Homebrew/libsoup_bottle_manifest--2.72.0... (17.3KB)
# Removing: /Users/oak/Library/Caches/Homebrew/vala_bottle_manifest--0.52.3... (13.4KB)
# Removing: /Users/oak/Library/Logs/Homebrew/rubberband... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libpsl... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/faad2... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/lame... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/pkg-config... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/glib-networking... (192B)
# Removing: /Users/oak/Library/Logs/Homebrew/libtiff... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libtool... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/gmp... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/wget... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/ffmpeg... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/xorgproto... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libidn2... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/xvid... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libshout... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/nghttp2... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libxau... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/little-cms2... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libsoup... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libpng... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/pygobject3... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/gst-libav... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/taglib... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/frei0r... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/gtk+3... (3 files, 1.6KB)
# Removing: /Users/oak/Library/Logs/Homebrew/nettle... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/pixman... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/gdbm... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/mpdecimal... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libxdmcp... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/cmake... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/opus... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/freetype... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/rtmpdump... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libsamplerate... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libvorbis... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/gts... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libunistring... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/pango... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/openjpeg... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/zimg... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/jemalloc... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/gdk-pixbuf... (204B)
# Removing: /Users/oak/Library/Logs/Homebrew/bdw-gc... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/speex... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libogg... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/icu4c... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/zeromq... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/atk... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/harfbuzz... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libbluray... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/glib... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libxcb... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/readline... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/netpbm... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libreplaygain... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/aom... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/graphite2... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/srt... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/tesseract... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/cairo... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/webp... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/sqlite... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/c-ares... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/gobject-introspection... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/gst-plugins-bad... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/fribidi... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libpthread-stubs... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/xz... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/fontconfig... (73.8KB)
# Removing: /Users/oak/Library/Logs/Homebrew/gst-plugins-base... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/gst-python... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/musepack... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/giflib... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libvpx... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libxrender... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/snappy... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/flac... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/gettext... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/graphene... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/vala... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/librsvg... (194B)
# Removing: /Users/oak/Library/Logs/Homebrew/graphviz... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libsodium... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/dav1d... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/opencore-amr... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/rav1e... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libxext... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/hicolor-icon-theme... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/m4... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libtasn1... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libcuefile... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/gd... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libusrsctp... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libevent... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/openssl@1.1... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/gstreamer... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/leptonica... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/pcre... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/x264... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libepoxy... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libvidstab... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/faac... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/orc... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/six... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/x265... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libsoxr... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/unbound... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/jpeg... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libmms... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/theora... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libnice... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/sdl2... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/srtp... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/libass... (64B)
# Removing: /Users/oak/Library/Logs/Homebrew/guile... (64B)
# ...
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/py3cairo/blobs/sha256:a14c31fed
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/manifests/10.86.24
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/1d4a00ab45f461fa1aa0b1f10c74667def11f02aeb7ab377ff22b0659b7e4985--netpbm-10.86.24.bottle_manifest.json
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/blobs/sha256:4c613179e8a
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/2430d35b77bb521f74458efa965b6c2f1ba663d541a7d3888add265353cbd2b1--netpbm--10.86.24.catalina.bottle.tar.gz
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2021.5
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/9f6b52cd905bc48a25a565843ed9fdee4d30ecdee5396b5b28793ce54643f95e--xorgproto-2021.5.bottle_manifest.json
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/blobs/sha256:97763c11
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/5946a337a26775ced4269006e951006bb631c3a549c4959d32e2fcbb44483ba1--xorgproto--2021.5.all.bottle.tar.gz
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.7.2
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/226f97cf7b3069e54ea53c2b2b557264eb2da1132dd85cb8f1e0c93c7981d09c--libx11-1.7.2.bottle_manifest.json
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/blobs/sha256:d7dede75032
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/9713918b42b4520c0d2284ff295e2fffb616eccbea49cbbc80f753f77d2b64bb--libx11--1.7.2.catalina.bottle.tar.gz
# ==> Downloading https://ghcr.io/v2/homebrew/core/gobject-introspection/manifests
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/06d0847a39d990c337cf4b3194c505c0a576e938bc2e22825359dabf17a8cf65--gobject-introspection-1.70.0.bottle_manifest.json
# ==> Downloading https://ghcr.io/v2/homebrew/core/gobject-introspection/blobs/sha
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/09359f997a1cf8a5bd9cde2fa6165b2e9d3aa7cfc0e0ea7f107ba6ed29cdac99--gobject-introspection--1.70.0.catalina.bottle.tar.gz
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/3.0.0
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/353ae89904837ddbfabb99cb52cf1e0aaf98795d231c403b441718a0f7f9b152--harfbuzz-3.0.0.bottle_manifest.json
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:f92aed1f3
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/4635e5789776588e9612a54158a3dd7db8085eb7b85988dd49a113b498a85eb1--harfbuzz--3.0.0.catalina.bottle.tar.gz
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/manifests/1.48.10
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/7316bd778212e370ed0c36eef1efeba87938d247cdb372d8e83521638e0cc832--pango-1.48.10.bottle_manifest.json
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/blobs/sha256:251360bab0dd
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/4400b5e9a4b69c7bc25ca90972833f21791ba04913f6ece9a3ff8114a7a77120--pango--1.48.10.catalina.bottle.tar.gz
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/manifests/2.50.7
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/b7a9768f72d0fbd34c04748f701fa5995b36aa536df4cf0fd1347cb208eebd57--librsvg-2.50.7.bottle_manifest.json
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/blobs/sha256:454d94e2c7
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/2a4fd7a8b5a81508e89f9c9a51341a3e4646a2887a0d4c9ba6a5654c14adeab9--librsvg--2.50.7.catalina.bottle.tar.gz
# ==> Downloading https://ghcr.io/v2/homebrew/core/m4/manifests/1.4.19
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/5b2a7f715487b7377e409e8ca58569040cd89f33859f691210c58d94410fd33b--m4-1.4.19.bottle_manifest.json
# ==> Downloading https://ghcr.io/v2/homebrew/core/m4/blobs/sha256:e0fec6a49fd80cc
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/541ca473156643175f4816b3fbc8ca12caab0487ecddcefa7198de0958f54555--m4--1.4.19.catalina.bottle.tar.gz
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/manifests/2.4.6_4
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/bcd85538886b3ea326aaffb13dda86069a6e8906ff0d950d0838ea938751f29b--libtool-2.4.6_4.bottle_manifest.json
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/blobs/sha256:ad541ac37b
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/acc032f536274e36547dfcd08a9288a48ea30664e43c065ebde6edd0dc6566fb--libtool--2.4.6_4.catalina.bottle.tar.gz
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/manifests/2.49.0
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/7430abe4127c0558d500b46e4ad883499cca6400cd6ed30172c4b9a8d6649367--graphviz-2.49.0.bottle_manifest.json
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/blobs/sha256:aeba9f5db
# Already downloaded: /Users/oak/Library/Caches/Homebrew/downloads/01ac259f0b23085f5b23429b2d7d470a02ba86d8f345b3b8ad605c518a240ee5--graphviz--2.49.0.catalina.bottle.tar.gz
# ==> Downloading https://ghcr.io/v2/homebrew/core/vala/manifests/0.54.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/vala/blobs/sha256:7ce14682f2f90
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Upgrading wget
#   1.21.1 -> 1.21.2
#
# ==> Installing dependencies for wget: libidn2
# ==> Installing wget dependency: libidn2
# ==> Pouring libidn2--2.3.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libidn2/2.3.2: 77 files, 846.5KB
# ==> Installing wget
# ==> Pouring wget--1.21.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/wget/1.21.2: 89 files, 4.2MB
# Removing: /usr/local/Cellar/wget/1.21.1... (88 files, 4MB)
# ==> Upgrading nghttp2
#   1.43.0 -> 1.44.0
#
# ==> Installing dependencies for nghttp2: c-ares
# ==> Installing nghttp2 dependency: c-ares
# ==> Pouring c-ares--1.17.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/c-ares/1.17.2: 85 files, 642.4KB
# ==> Installing nghttp2
# ==> Pouring nghttp2--1.44.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/nghttp2/1.44.0: 23 files, 2.8MB
# Removing: /usr/local/Cellar/nghttp2/1.43.0... (24 files, 2.8MB)
# ==> Upgrading unbound
#   1.13.1 -> 1.13.2
#
# ==> Pouring unbound--1.13.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/unbound/1.13.2: 57 files, 5.7MB
# Removing: /usr/local/Cellar/unbound/1.13.1... (57 files, 5.4MB)
# ==> Upgrading gnutls
#   3.6.15 -> 3.6.16
#
# ==> Installing dependencies for gnutls: gmp, m4, libtool, nettle and p11-kit
# ==> Installing gnutls dependency: gmp
# ==> Pouring gmp--6.2.1_1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/gmp/6.2.1_1: 21 files, 3.3MB
# ==> Installing gnutls dependency: m4
# ==> Pouring m4--1.4.19.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/m4/1.4.19: 13 files, 724.4KB
# ==> Installing gnutls dependency: libtool
# ==> Pouring libtool--2.4.6_4.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libtool/2.4.6_4: 75 files, 3.7MB
# ==> Installing gnutls dependency: nettle
# ==> Pouring nettle--3.7.3.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/nettle/3.7.3: 89 files, 2.7MB
# ==> Installing gnutls dependency: p11-kit
# ==> Pouring p11-kit--0.24.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/p11-kit/0.24.0: 63 files, 3.1MB
# ==> Installing gnutls
# ==> Pouring gnutls--3.6.16.catalina.bottle.tar.gz
# ==> Regenerating CA certificate bundle from keychain, this may take a while...
# 🍺  /usr/local/Cellar/gnutls/3.6.16: 1,250 files, 11MB
# Removing: /usr/local/Cellar/gnutls/3.6.15... (1,250 files, 11MB)
# ==> Upgrading gsettings-desktop-schemas
#   40.0 -> 41.0
#
# ==> Pouring gsettings-desktop-schemas--41.0.catalina.bottle.tar.gz
# ==> /usr/local/opt/glib/bin/glib-compile-schemas /usr/local/share/glib-2.0/schem
# 🍺  /usr/local/Cellar/gsettings-desktop-schemas/41.0: 97 files, 4.7MB
# Removing: /usr/local/Cellar/gsettings-desktop-schemas/40.0... (97 files, 4.6MB)
# ==> Upgrading glib-networking
#   2.68.1 -> 2.70.0
#
# ==> Pouring glib-networking--2.70.0.catalina.bottle.tar.gz
# ==> /usr/local/opt/glib/bin/gio-querymodules /usr/local/lib/gio/modules
# 🍺  /usr/local/Cellar/glib-networking/2.70.0: 75 files, 650.8KB
# Removing: /usr/local/Cellar/glib-networking/2.68.1... (75 files, 621KB)
# ==> Upgrading gobject-introspection
#   1.68.0 -> 1.70.0
#
# ==> Installing dependencies for gobject-introspection: xorgproto and libx11
# ==> Installing gobject-introspection dependency: xorgproto
# ==> Pouring xorgproto--2021.5.all.bottle.tar.gz
# 🍺  /usr/local/Cellar/xorgproto/2021.5: 264 files, 3.9MB
# ==> Installing gobject-introspection dependency: libx11
# ==> Pouring libx11--1.7.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libx11/1.7.2: 1,055 files, 7MB
# ==> Installing gobject-introspection
# ==> Pouring gobject-introspection--1.70.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/gobject-introspection/1.70.0: 191 files, 12.9MB
# Removing: /usr/local/Cellar/gobject-introspection/1.68.0... (190 files, 12.7MB)
# ==> Upgrading harfbuzz
#   2.8.1 -> 3.0.0
#
# ==> Pouring harfbuzz--3.0.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/harfbuzz/3.0.0: 68 files, 7.3MB
# Removing: /usr/local/Cellar/harfbuzz/2.8.1... (68 files, 7MB)
# ==> Upgrading netpbm
#   10.86.21 -> 10.86.24
#
# ==> Pouring netpbm--10.86.24.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/netpbm/10.86.24: 410 files, 17.7MB
# Removing: /usr/local/Cellar/netpbm/10.86.21... (410 files, 17.7MB)
# ==> Upgrading pango
#   1.48.4 -> 1.48.10
#
# ==> Pouring pango--1.48.10.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/pango/1.48.10: 65 files, 3.0MB
# Removing: /usr/local/Cellar/pango/1.48.4... (64 files, 2.9MB)
# ==> Upgrading librsvg
#   2.50.5 -> 2.50.7
#
# ==> Pouring librsvg--2.50.7.catalina.bottle.tar.gz
# ==> /usr/local/opt/gdk-pixbuf/bin/gdk-pixbuf-query-loaders --update-cache
# 🍺  /usr/local/Cellar/librsvg/2.50.7: 48 files, 138.6MB
# Removing: /usr/local/Cellar/librsvg/2.50.5... (48 files, 148.6MB)
# ==> Upgrading graphviz
#   2.47.1 -> 2.49.0
#
# ==> Pouring graphviz--2.49.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/graphviz/2.49.0: 301 files, 8.1MB
# Removing: /usr/local/Cellar/graphviz/2.47.1... (301 files, 8.2MB)
# ==> Upgrading gtk+3
#   3.24.29 -> 3.24.30
#
# ==> Installing dependencies for gtk+3: libepoxy
# ==> Installing gtk+3 dependency: libepoxy
# ==> Pouring libepoxy--1.5.9.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libepoxy/1.5.9: 10 files, 2.5MB
# ==> Installing gtk+3
# ==> Pouring gtk+3--3.24.30.catalina.bottle.tar.gz
# ==> /usr/local/opt/glib/bin/glib-compile-schemas /usr/local/share/glib-2.0/schem
# ==> /usr/local/Cellar/gtk+3/3.24.30/bin/gtk3-update-icon-cache -f -t /usr/local/
# ==> /usr/local/Cellar/gtk+3/3.24.30/bin/gtk-query-immodules-3.0 > /usr/local/lib
# 🍺  /usr/local/Cellar/gtk+3/3.24.30: 722 files, 52.7MB
# Removing: /usr/local/Cellar/gtk+3/3.24.29... (717 files, 52.1MB)
# ==> Upgrading leptonica
#   1.80.0 -> 1.81.1
#
# ==> Pouring leptonica--1.81.1.catalina.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/leptonica/1.81.1: 53 files, 6.3MB
# Removing: /usr/local/Cellar/leptonica/1.80.0... (52 files, 6MB)
# ==> Upgrading libass
#   0.15.1 -> 0.15.2
#
# ==> Pouring libass--0.15.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libass/0.15.2: 11 files, 580.8KB
# Removing: /usr/local/Cellar/libass/0.15.1... (10 files, 576.2KB)
# ==> Upgrading ffmpeg
#   4.4_1 -> 4.4_2
#
# ==> Installing dependencies for ffmpeg: aom, dav1d, libogg, libvpx, rubberband, sdl2, snappy, x264 and zimg
# ==> Installing ffmpeg dependency: aom
# ==> Pouring aom--3.1.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/aom/3.1.2: 22 files, 12.6MB
# ==> Installing ffmpeg dependency: dav1d
# ==> Pouring dav1d--0.9.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/dav1d/0.9.2: 15 files, 2.0MB
# ==> Installing ffmpeg dependency: libogg
# ==> Pouring libogg--1.3.5.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libogg/1.3.5: 97 files, 513.5KB
# ==> Installing ffmpeg dependency: libvpx
# ==> Pouring libvpx--1.10.0_1.catalina.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/libvpx/1.10.0_1: 20 files, 5.2MB
# ==> Installing ffmpeg dependency: rubberband
# ==> Pouring rubberband--1.9.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/rubberband/1.9.2: 12 files, 1MB
# ==> Installing ffmpeg dependency: sdl2
# ==> Pouring sdl2--2.0.16.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/sdl2/2.0.16: 91 files, 5.3MB
# ==> Installing ffmpeg dependency: snappy
# ==> Pouring snappy--1.1.9.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/snappy/1.1.9: 18 files, 163.1KB
# ==> Installing ffmpeg dependency: x264
# ==> Pouring x264--r3060.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/x264/r3060: 11 files, 5.7MB
# ==> Installing ffmpeg dependency: zimg
# ==> Pouring zimg--3.0.3.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/zimg/3.0.3: 27 files, 2.3MB
# ==> Installing ffmpeg
# ==> Pouring ffmpeg--4.4_2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/ffmpeg/4.4_2: 276 files, 52.7MB
# Removing: /usr/local/Cellar/ffmpeg/4.4_1... (276 files, 52.7MB)
# ==> Upgrading libsoup
#   2.72.0 -> 2.74.0_1
#
# ==> Pouring libsoup--2.74.0_1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libsoup/2.74.0_1: 146 files, 2.9MB
# Removing: /usr/local/Cellar/libsoup/2.72.0... (146 files, 2.8MB)
# ==> Upgrading py3cairo
#   1.20.0_1 -> 1.20.1
#
# ==> Pouring py3cairo--1.20.1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/py3cairo/1.20.1: 18 files, 400.3KB
# Removing: /usr/local/Cellar/py3cairo/1.20.0_1... (18 files, 398.5KB)
# ==> Upgrading vala
#   0.52.3 -> 0.54.0
#
# ==> Pouring vala--0.54.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/vala/0.54.0: 385 files, 14MB
# Removing: /usr/local/Cellar/vala/0.52.3... (389 files, 14.2MB)
# ==> Checking for dependents of upgraded formulae...
# ==> No broken dependents found!
# ==> Caveats
# ==> qt@5
# We agreed to the Qt open source license for you.
# If this is unacceptable you should uninstall.
#
# qt@5 is keg-only, which means it was not symlinked into /usr/local,
# because this is an alternate version of another formula.
#
# If you need to have qt@5 first in your PATH, run:
#   echo 'export PATH="/usr/local/opt/qt@5/bin:$PATH"' >> ~/.zshrc
#
# For compilers to find qt@5 you may need to set:
#   export LDFLAGS="-L/usr/local/opt/qt@5/lib"
#   export CPPFLAGS="-I/usr/local/opt/qt@5/include"
#
# For pkg-config to find qt@5 you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/qt@5/lib/pkgconfig"
#
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxml2/manifests/2.9.12
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxml2/blobs/sha256:eb2c8a444b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Pouring libxml2--2.9.12.catalina.bottle.tar.gz
# ==> Caveats
# libxml2 is keg-only, which means it was not symlinked into /usr/local,
# because macOS already provides this software and installing another version in
# parallel can cause all kinds of trouble.
#
# If you need to have libxml2 first in your PATH, run:
#   echo 'export PATH="/usr/local/opt/libxml2/bin:$PATH"' >> ~/.zshrc
#
# For compilers to find libxml2 you may need to set:
#   export LDFLAGS="-L/usr/local/opt/libxml2/lib"
#   export CPPFLAGS="-I/usr/local/opt/libxml2/include"
#
# For pkg-config to find libxml2 you may need to set:
#   export PKG_CONFIG_PATH="/usr/local/opt/libxml2/lib/pkgconfig"
#
# ==> Summary
# 🍺  /usr/local/Cellar/libxml2/2.9.12: 280 files, 10.6MB
# ==> Downloading https://ghcr.io/v2/homebrew/core/pyqt/5/manifests/5.15.4_2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pyqt/5/blobs/sha256:70bc904d9ef
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Pouring pyqt@5--5.15.4_2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/pyqt@5/5.15.4_2: 1,327 files, 31.6MB

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}

# %%
if os.name == 'posix':
    # !cd {LABELIMG_PATH} && make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/0.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/0.xml
# Cancel creation.
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/1.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/1.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/1.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/1.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/2.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/2.xml
# labelImg.py:965: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   bar.setValue(bar.value() + bar.singleStep() * units)
# Cancel creation.
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/3.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/3.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/4.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/4.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/5.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/5.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/6.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/6.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/7.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/7.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/8.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/8.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/9.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/9.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/10.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/10.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/11.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/11.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/12.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/12.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/13.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/13.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/14.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/14.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/15.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/15.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/16.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/16.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/17.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/17.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/18.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/18.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/19.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/19.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/20.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/20.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/21.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/21.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/22.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/22.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/23.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/23.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/24.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/24.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/25.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/25.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/26.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/26.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/27.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/27.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/28.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/28.xml
# qt.gui.icc: Unsupported ICC profile class 73706163
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/29.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/29.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/30.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/rust/30.xml
# Cancel creation.
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/0.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/0.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/1.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/1.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/2.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/2.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/3.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/3.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/4.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/4.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/5.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/5.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/6.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/6.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/7.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/7.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/8.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/8.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/9.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/9.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/10.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/10.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/11.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/11.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/12.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/12.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/13.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/13.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/14.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/14.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/15.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/15.xml
# Image:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/16.jpeg -> Annotation:/Users/oak/Documents/GitHub/option/Tensorflow/workspace/images/collectedimages/norust/16.xml
# QICNSHandler::read(): Failed, compressed format "unknown" is not supported by your Qt library or this file is corrupt. OSType: ""
